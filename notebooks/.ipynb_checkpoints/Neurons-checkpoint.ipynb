# %%
# basic of neurons
inputs = [1.2, 5.1, 2.1]
weights = [3.1, 2.1, 8.7]
bisas = 3
output = []

for i in range(len(inputs)):
    output2 = inputs[i]*weights[i]
    output.append(output2)
sum(output)+bisas
# Out:
# 35.699999999999996

# %%
# conmparison
outpu3 = inputs[0]*weights[0]+ inputs[1]*weights[1]+ inputs[2]*weights[2]+bisas
outpu3
# Out:
# 35.7
