# %%
# basic of neurons
inputs = [1, 2, 3,2.5]
weights1 = [0.2, 0.8, -0.5, 1.0]
weights2 = [0.5, -0.91, 0.26, -0.5]
weights3 = [-0.26, -0.27, 0.17, 0.87]

bisas1 = 2
bisas2 = 3
bisas3 = 0.5
output = []

# %%
# conmparison
list_of_output = [ inputs[0]*weights1[0]+ inputs[1]*weights1[1]+ inputs[2]*weights1[2]+inputs[3]*weights1[3]+bisas1,  
                   inputs[0]*weights2[0]+ inputs[1]*weights2[1]+ inputs[2]*weights2[2]+inputs[3]*weights2[3]+bisas2, 
                   inputs[0]*weights3[0]+ inputs[1]*weights3[1]+ inputs[2]*weights3[2]+inputs[3]*weights3[3]+bisas3
                 ]
print(list_of_output)
# Out:
# [4.8, 1.21, 2.385]

# %%
# using more dynamic way 
inputs = [1, 2, 3,2.5]
weights = [
    [0.2, 0.8, -0.5, 1.0],
    [0.5,-0.91, 0.26, -0.5],
    [-0.26, -0.27, 0.17, 0.87] 
    ]
biases = [2,3,0.5]
zipped =zip(weights,biases)
print(tuple(zipped))
# Out:
# (([0.2, 0.8, -0.5, 1.0], 2), ([0.5, -0.91, 0.26, -0.5], 3), ([-0.26, -0.27, 0.17, 0.87], 0.5))

# %%
layer_outputs = [] # output of current layer
for neuron_weights,neuron_bias in zip(weights, biases):
    neuron_output = 0 # output of given neuron
    for n_input, weight in zip(inputs,neuron_weights):
        neuron_output += n_input*weight
    neuron_output +=neuron_bias
    layer_outputs.append(neuron_output)
print(layer_outputs)
# Out:
# [4.8, 1.21, 2.385]

# %%
# dot product 
import numpy as np
inputs = [1, 2, 3,2.5]
weights1 = [0.2, 0.8, -0.5, 1.0]
bias = 2
output = np.dot(inputs, weights1)+bias
print(output)
# Out:
# 4.8

# %%
inputs = [1, 2, 3,2.5]
weights = [
    [0.2, 0.8, -0.5, 1.0],
    [0.5,-0.91, 0.26, -0.5],
    [-0.26, -0.27, 0.17, 0.87] 
    ]
biases = [2,3,0.5]
output = np.dot(weights,inputs)+biases
print(output)
# Out:
# [4.8   1.21  2.385]

# %% [markdown]
# ## How Does that Dot Product actually working

# %%
output_detail = [np.dot(weights[0],inputs),
                np.dot(weights[1],inputs),
                np.dot(weights[2], inputs),
                ]
bias = np.array(biases)
print(output_detail + bias )
# Out:
# [4.8   1.21  2.385]

# %% [markdown]
# ## Layer 1

# %%
inputs_layer1 = [
    [1,2,3,2.5],
    [2.0,5.0,-1.0,2.0],
    [-1.5,2.7,3.3,-0.8],
    ]

weights_layer1 = [
    [0.2, 0.8, -0.5, 1.0],
    [0.5,-0.91, 0.26, -0.5],
    [-0.26, -0.27, 0.17, 0.87] 
    ]
bias_layer1 = [2,3,0.5]
out_put_layer1 = np.dot(inputs_layer1,np.array(weights_layer1).T)+bias_layer1
out_put_layer1
# Out:
# array([[ 4.8  ,  1.21 ,  2.385],
#        [ 8.9  , -1.81 ,  0.2  ],
#        [ 1.41 ,  1.051,  0.026]])

# %% [markdown]
# ## layer 2

# %%
weights_layer2 = [
[0.1,-0.14,0.5],
[-0.5,0.12,-0.33],
[-0.44, 0.73, -0.13]
]
bias_layer2 = [-1,2,-0.5]
out_put_layer2 = np.dot(out_put_layer1, np.array(weights_layer2).T)+bias_layer2
out_put_layer2
# Out:
# array([[ 0.5031 , -1.04185, -2.03875],
#        [ 0.2434 , -2.7332 , -5.7633 ],
#        [-0.99314,  1.41254, -0.35655]])

# %%
import nnfs
from nnfs.datasets import spiral_data
nnfs.init()

X,y = spiral_data(100,3)


class Layer_Dense:
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.1*np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1,n_neurons))
        
    def forward(self,inputs):
        self.output = np.dot(inputs,self.weights)+ self.biases

class Activation_ReLu:
    def forward(self,inputs):
        self.output = np.maximum(0,inputs)

class Activation_softmax:
    def forward(self, inputs):
        exp_values = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))
        probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)
        self.output = probabilities

# %%
layer1 = Layer_Dense(2,5)
activation1 = Activation_ReLu()
layer2 = Layer_Dense(5,3)
activation2 = Activation_softmax()
layer1.forward(X)
activation1.forward(layer1.output)
layer2.forward(activation1.output)
activation2.forward(layer2.output)
activation2.output
# Out:
# array([[0.33333334, 0.33333334, 0.33333334],
#        [0.33334842, 0.33336917, 0.33328238],
#        [0.3333046 , 0.33334762, 0.3333478 ],
#        [0.33322504, 0.33326083, 0.3335141 ],
#        [0.33318785, 0.33323595, 0.3335762 ],
#        [0.33354065, 0.33364868, 0.33281067],
#        [0.333129  , 0.3332371 , 0.33363393],
#        [0.33325806, 0.3334059 , 0.33333603],
#        [0.33318755, 0.3333621 , 0.33345032],
#        [0.33302015, 0.33316457, 0.33381528],
#        [0.33299252, 0.33317202, 0.33383545],
#        [0.3329909 , 0.33310404, 0.33390504],
#        [0.33291587, 0.33305377, 0.33403036],
#        [0.33286154, 0.33301732, 0.33412114],
#        [0.3328533 , 0.3330118 , 0.3341349 ],
#        [0.33282796, 0.33299485, 0.33417723],
#        [0.33325046, 0.33311808, 0.3336315 ],
#        [0.33274603, 0.3329399 , 0.33431405],
#        [0.33287188, 0.3329857 , 0.33414236],
#        [0.3326551 , 0.33287892, 0.33446598],
#        [0.33298394, 0.33341914, 0.3335969 ],
#        [0.33332282, 0.333084  , 0.33359322],
#        [0.33357176, 0.33316392, 0.33326435],
#        [0.3327184 , 0.3328831 , 0.33439854],
#        [0.33395678, 0.33324358, 0.33279958],
#        [0.33253655, 0.33279938, 0.33466402],
#        [0.33360767, 0.3331302 , 0.33326218],
#        [0.3335955 , 0.3331136 , 0.33329087],
#        [0.3340573 , 0.33322906, 0.33271363],
#        [0.33414027, 0.3333297 , 0.33253002],
#        [0.33407384, 0.3332267 , 0.33269948],
#        [0.33413783, 0.33321744, 0.33264473],
#        [0.33390877, 0.33317935, 0.33291185],
#        [0.33312547, 0.3328773 , 0.3339972 ],
#        [0.3342075 , 0.33320737, 0.3325851 ],
#        [0.33425295, 0.33322996, 0.3325171 ],
#        [0.3321163 , 0.3321302 , 0.33575347],
#        [0.33247888, 0.33398834, 0.3335328 ],
#        [0.3351179 , 0.33307496, 0.33180714],
#        [0.33324784, 0.33245003, 0.3343021 ],
#        [0.3315846 , 0.33193755, 0.33647785],
#        [0.33246967, 0.33217356, 0.3353568 ],
#        [0.3347106 , 0.33297104, 0.3323184 ],
#        [0.33388466, 0.33263218, 0.33348316],
#        [0.33075774, 0.3316027 , 0.33763954],
#        [0.3359884 , 0.33426362, 0.32974797],
#        [0.3351163 , 0.3330752 , 0.33180854],
#        [0.33543938, 0.3330279 , 0.33153272],
#        [0.33487573, 0.3329659 , 0.33215836],
#        [0.3363644 , 0.33493295, 0.32870266],
#        [0.33552912, 0.33301473, 0.33145612],
#        [0.3359284 , 0.3337626 , 0.33030906],
#        [0.335395  , 0.33303443, 0.3315706 ],
#        [0.33705845, 0.33577436, 0.3271672 ],
#        [0.33666694, 0.33539966, 0.3279334 ],
#        [0.33804956, 0.3373786 , 0.3245718 ],
#        [0.33578554, 0.33321816, 0.33099627],
#        [0.33625785, 0.33410046, 0.32964176],
#        [0.33995238, 0.34177834, 0.31826925],
#        [0.3361051 , 0.33366582, 0.3302291 ],
#        [0.33746934, 0.33602217, 0.32650852],
#        [0.3395458 , 0.34111646, 0.31933773],
#        [0.3387761 , 0.3385273 , 0.32269663],
#        [0.33956805, 0.34089088, 0.31954107],
#        [0.33873427, 0.3382639 , 0.3230018 ],
#        [0.33986846, 0.34153572, 0.3185958 ]], dtype=float32)

# %% [markdown]
# ## RELU Activation Function

# %%
inputs_for_relu = [0,2,-1,3.3,-2.7,1.1,2.2,-100]
outputs_of_relu = []
for i in inputs_for_relu:
    if i>0:
        outputs_of_relu.append(i)
    elif i<=0:
        outputs_of_relu.append(0)
print(outputs_of_relu)
# Out:
# [0, 2, 0, 3.3, 0, 1.1, 2.2, 0]

# %% [markdown]
# ## softmax Function

# %%
import math
layer_outputs = [4.8, 1.21, 2.385]
E = math.e
exp_values = []
for output in layer_outputs:
    exp_values.append(E**output)
print(exp_values)
norm_base = sum(exp_values)
norm_value = []

for values in exp_values:
    norm_value.append(values/norm_base)
print(norm_value)
print(sum(norm_value))
# Out:
# [121.51041751873483, 3.353484652549023, 10.859062664920513]
# [0.8952826639572619, 0.024708306782099374, 0.0800090292606387]
# 0.9999999999999999

# %% [markdown]
# ## softmax for batch

# %%
import numpy as np

layer_output = [
    [4.8, 1.21, 2.385],
    [8.9, -1.81, 0.2],
    [1.41, 1.051, 0.026]
]

exp_values = np.exp(layer_output)
print(exp_values)
sums = np.sum(exp_values, axis=1, keepdims=True)
print(sums)
# Out:
# [[1.21510418e+02 3.35348465e+00 1.08590627e+01]
#  [7.33197354e+03 1.63654137e-01 1.22140276e+00]
#  [4.09595540e+00 2.86051020e+00 1.02634095e+00]]
# [[ 135.72296484]
#  [7333.35859605]
#  [   7.98280655]]
