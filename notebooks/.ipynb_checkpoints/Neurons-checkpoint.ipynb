# %%
# basic of neurons
inputs = [1, 2, 3,2.5]
weights1 = [0.2, 0.8, -0.5, 1.0]
weights2 = [0.2, 0.8, -0.5, 1.0]
weights3 = [0.2, 0.8, -0.5, 1.0]

bisas1 = 2
bisas2 = 2
bisas3 = 2
output = []

for i in range(len(inputs)):
    output2 = inputs[i]*weights[i]
    output.append(output2)
sum(output)+bisas
# Out:
# 4.800000000000001

# %%
# conmparison
outpu1 = inputs[0]*weights1[0]+ inputs[1]*weights1[1]+ inputs[2]*weights1[2]+inputs[3]*weights1[3]+bisas1
outpu2 = inputs[0]*weights2[0]+ inputs[1]*weights2[1]+ inputs[2]*weights2[2]+inputs[3]*weights2[3]+bisas2
outpu3 = inputs[0]*weights3[0]+ inputs[1]*weights3[1]+ inputs[2]*weights3[2]+inputs[3]*weights3[3]+bisas3
print(outpu1)
print(outpu2)
print(outpu3)
# Out:
# 4.8
# 4.8
# 4.8
