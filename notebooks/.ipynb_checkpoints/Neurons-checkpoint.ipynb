# %%
# basic of neurons
inputs = [1, 2, 3,2.5]
weights1 = [0.2, 0.8, -0.5, 1.0]
weights2 = [0.5, -0.91, 0.26, -0.5]
weights3 = [-0.26, -0.27, 0.17, 0.87]

bisas1 = 2
bisas2 = 3
bisas3 = 0.5
output = []

# %%
# conmparison
list_of_output = [ inputs[0]*weights1[0]+ inputs[1]*weights1[1]+ inputs[2]*weights1[2]+inputs[3]*weights1[3]+bisas1,  
                   inputs[0]*weights2[0]+ inputs[1]*weights2[1]+ inputs[2]*weights2[2]+inputs[3]*weights2[3]+bisas2, 
                   inputs[0]*weights3[0]+ inputs[1]*weights3[1]+ inputs[2]*weights3[2]+inputs[3]*weights3[3]+bisas3
                 ]
print(list_of_output)
# Out:
# [4.8, 1.21, 2.385]

# %%
# using more dynamic way 
inputs = [1, 2, 3,2.5]
weights = [
    [0.2, 0.8, -0.5, 1.0],
    [0.5,-0.91, 0.26, -0.5],
    [-0.26, -0.27, 0.17, 0.87] 
    ]
biases = [2,3,0.5]
zipped =zip(weights,biases)
print(tuple(zipped))
# Out:
# (([0.2, 0.8, -0.5, 1.0], 2), ([0.5, -0.91, 0.26, -0.5], 3), ([-0.26, -0.27, 0.17, 0.87], 0.5))

# %%
layer_outputs = [] # output of current layer
for neuron_weights,neuron_bias in zip(weights, biases):
    neuron_output = 0 # output of given neuron
    for n_input, weight in zip(inputs,neuron_weights):
        neuron_output += n_input*weight
    neuron_output +=neuron_bias
    layer_outputs.append(neuron_output)
print(layer_outputs)
# Out:
# [4.8, 1.21, 2.385]

# %%
# dot product 
import numpy as np
inputs = [1, 2, 3,2.5]
weights1 = [0.2, 0.8, -0.5, 1.0]
bias = 2
output = np.dot(inputs, weights1)+bias
print(output)
# Out:
# 4.8

# %%
inputs = [1, 2, 3,2.5]
weights = [
    [0.2, 0.8, -0.5, 1.0],
    [0.5,-0.91, 0.26, -0.5],
    [-0.26, -0.27, 0.17, 0.87] 
    ]
biases = [2,3,0.5]
output = np.dot(weights,inputs)+biases
print(output)
# Out:
# [4.8   1.21  2.385]

# %% [markdown]
# ## How Does that Dot Product actually working

# %%
output_detail = [np.dot(weights[0],inputs),
                np.dot(weights[1],inputs),
                np.dot(weights[2], inputs),
                ]
bias = np.array(biases)
print(output_detail + bias )
# Out:
# [4.8   1.21  2.385]

# %% [markdown]
# ## Layer 1

# %%
inputs_layer1 = [
    [1,2,3,2.5],
    [2.0,5.0,-1.0,2.0],
    [-1.5,2.7,3.3,-0.8],
    ]

weights_layer1 = [
    [0.2, 0.8, -0.5, 1.0],
    [0.5,-0.91, 0.26, -0.5],
    [-0.26, -0.27, 0.17, 0.87] 
    ]
bias_layer1 = [2,3,0.5]
out_put_layer1 = np.dot(inputs_layer1,np.array(weights_layer1).T)+bias_layer1
out_put_layer1
# Out:
# array([[ 4.8  ,  1.21 ,  2.385],
#        [ 8.9  , -1.81 ,  0.2  ],
#        [ 1.41 ,  1.051,  0.026]])

# %% [markdown]
# ## layer 2

# %%
weights_layer2 = [
[0.1,-0.14,0.5],
[-0.5,0.12,-0.33],
[-0.44, 0.73, -0.13]
]
bias_layer2 = [-1,2,-0.5]
out_put_layer2 = np.dot(out_put_layer1, np.array(weights_layer2).T)+bias_layer2
out_put_layer2
# Out:
# array([[ 0.5031 , -1.04185, -2.03875],
#        [ 0.2434 , -2.7332 , -5.7633 ],
#        [-0.99314,  1.41254, -0.35655]])

# %%
import nnfs
from nnfs.datasets import spiral_data
nnfs.init()

X,y = spiral_data(100,3)


class Layer_Dense:
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.1*np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1,n_neurons))
        
    def forward(self,inputs):
        self.output = np.dot(inputs,self.weights)+ self.biases

class Activation_ReLu:
    def forward(self,inputs):
        self.output = np.maximum(0,inputs)

class Activation_softmax:
    def forward(self, inputs):
        exp_values = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))
        probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)
        self.output = probabilities

# %%
layer1 = Layer_Dense(2,5)
activation1 = Activation_ReLu()
layer2 = Layer_Dense(5,3)
activation2 = Activation_softmax()
layer1.forward(X)
activation1.forward(layer1.output)
layer2.forward(activation1.output)
activation2.forward(layer2.output)
activation2.output
# Out:
# array([[0.33333334, 0.33333334, 0.33333334],
#        [0.33334148, 0.3333302 , 0.33332834],
#        [0.33335316, 0.33332598, 0.33332086],
#        [0.333332  , 0.33330762, 0.3333604 ],
#        [0.33333603, 0.33330083, 0.33336315],
#        [0.33338383, 0.33331344, 0.3333027 ],
#        [0.3333572 , 0.33329478, 0.33334807],
#        [0.33340374, 0.3333082 , 0.3332881 ],
#        [0.33339977, 0.33330202, 0.3332982 ],
#        [0.33336535, 0.3332733 , 0.33336142],
#        [0.33337295, 0.333269  , 0.33335805],
#        [0.3332787 , 0.33321112, 0.33351016],
#        [0.33330157, 0.33322194, 0.33347648],
#        [0.33333594, 0.33322513, 0.33343893],
#        [0.33328852, 0.33320144, 0.33351007],
#        [0.3332781 , 0.33318755, 0.33353442],
#        [0.33320153, 0.33311486, 0.33368364],
#        [0.33328357, 0.3331743 , 0.33354214],
#        [0.3332255 , 0.3331155 , 0.33365905],
#        [0.33330777, 0.33316433, 0.3335279 ],
#        [0.33350578, 0.33325595, 0.33323827],
#        [0.33315322, 0.33304507, 0.33380166],
#        [0.33313245, 0.33303663, 0.33383092],
#        [0.3331992 , 0.3330584 , 0.3337424 ],
#        [0.33319548, 0.33402708, 0.33277747],
#        [0.33321705, 0.3330639 , 0.33371902],
#        [0.33309618, 0.33298233, 0.33392152],
#        [0.3330878 , 0.33296782, 0.33394435],
#        [0.33319554, 0.33418608, 0.3326184 ],
#        [0.33323786, 0.3343008 , 0.3324614 ],
#        [0.33303356, 0.33348224, 0.33348423],
#        [0.33302498, 0.33386913, 0.3331059 ],
#        [0.33303618, 0.3329166 , 0.33404726],
#        [0.33306423, 0.3328837 , 0.33405206],
#        [0.33299318, 0.33380464, 0.3332022 ],
#        [0.33317634, 0.3344276 , 0.33239603],
#        [0.33344427, 0.33503562, 0.3315201 ],
#        [0.33347836, 0.33509934, 0.33142233],
#        [0.33319065, 0.33457118, 0.33223823],
#        [0.33256567, 0.33271563, 0.33471867],
#        [0.33286506, 0.3356774 , 0.33145756],
#        [0.3325699 , 0.3322771 , 0.33515304],
#        [0.33338758, 0.3370196 , 0.32959282],
#        [0.33272514, 0.33552286, 0.3317521 ],
#        [0.33323598, 0.3364837 , 0.33028033],
#        [0.33248204, 0.33337247, 0.33414546],
#        [0.3335987 , 0.3374569 , 0.3289444 ],
#        [0.3334625 , 0.3373574 , 0.32918006],
#        [0.33380824, 0.3375693 , 0.32862246],
#        [0.33298972, 0.33626574, 0.33074453],
#        [0.33335972, 0.3369086 , 0.32973164],
#        [0.33443815, 0.33570844, 0.3298534 ],
#        [0.33316806, 0.3366876 , 0.33014435],
#        [0.33364886, 0.3378079 , 0.32854322],
#        [0.3342765 , 0.33684883, 0.3288747 ],
#        [0.33392897, 0.33782616, 0.3282449 ],
#        [0.3342285 , 0.33716866, 0.32860285],
#        [0.33390313, 0.33796102, 0.3281359 ],
#        [0.33433354, 0.33692423, 0.3287422 ]], dtype=float32)

# %% [markdown]
# ## RELU Activation Function

# %%
inputs_for_relu = [0,2,-1,3.3,-2.7,1.1,2.2,-100]
outputs_of_relu = []
for i in inputs_for_relu:
    if i>0:
        outputs_of_relu.append(i)
    elif i<=0:
        outputs_of_relu.append(0)
print(outputs_of_relu)
# Out:
# [0, 2, 0, 3.3, 0, 1.1, 2.2, 0]

# %% [markdown]
# ## softmax Function

# %%
import math
layer_outputs = [4.8, 1.21, 2.385]
E = math.e
exp_values = []
for output in layer_outputs:
    exp_values.append(E**output)
print(exp_values)
norm_base = sum(exp_values)
norm_value = []

for values in exp_values:
    norm_value.append(values/norm_base)
print(norm_value)
print(sum(norm_value))
# Out:
# [121.51041751873483, 3.353484652549023, 10.859062664920513]
# [0.8952826639572619, 0.024708306782099374, 0.0800090292606387]
# 0.9999999999999999

# %% [markdown]
# ## softmax for batch

# %%
import numpy as np

layer_output = [
    [4.8, 1.21, 2.385],
    [8.9, -1.81, 0.2],
    [1.41, 1.051, 0.026]
]

exp_values = np.exp(layer_output)
print(exp_values)
sums = np.sum(exp_values, axis=1, keepdims=True)
print(sums)
# Out:
# [[1.21510418e+02 3.35348465e+00 1.08590627e+01]
#  [7.33197354e+03 1.63654137e-01 1.22140276e+00]
#  [4.09595540e+00 2.86051020e+00 1.02634095e+00]]
# [[ 135.72296484]
#  [7333.35859605]
#  [   7.98280655]]

# %% [markdown]
# ## Loss function

# %%
import math
softmax_output = [0.7,0.1, 0.2]
target_output = [1,0,0]
loss = -(math.log(softmax_output[0])*target_output[0]+
        math.log(softmax_output[1])*target_output[1]+
        math.log(softmax_output[2])*target_output[2]
        )
print(loss)
# Out:
# 0.35667494393873245

# %% [markdown]
# ## for Batch

# %%
softmax_outputs = np.array([[0.7,0.1, 0.2],
                           [0.1,0.5,0.4],
                           [0.02, 0.9, 0.08]])
class_targets = [0,1,1]
print(softmax_outputs[[0,1,2], class_targets])
# Out:
# [0.7 0.5 0.9]
