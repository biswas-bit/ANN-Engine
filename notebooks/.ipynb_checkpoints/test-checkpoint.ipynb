# %%
import numpy as np
from ann_engine.layers.layers import Dense
from ann_engine.layers import Sequential
from ann_engine.optimizers import Adam

# %%
X_train = np.random.randn(1000, 784)
y_train = np.random.randint(0, 10, (1000, 10))

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# %%
print(model)
# Out:
# <ann_engine.layers.sequential.Sequential object at 0x0000013C12121CA0>

# %%
model.compile(optimizer=Adam(lr=0.01),
             loss = 'categorical_crossentropy',
             metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=5, batch_size=32, verbose=1)
# Out:
# Epoch 1/5  loss: 119.1558  val_loss: 117.9941  accuracy: 0.0800  val_accuracy: 0.0700
# Epoch 2/5  loss: 119.1558  val_loss: 117.9941  accuracy: 0.0800  val_accuracy: 0.0700
# Epoch 3/5  loss: 119.1558  val_loss: 117.9941  accuracy: 0.0800  val_accuracy: 0.0700
# Epoch 4/5  loss: 119.1558  val_loss: 117.9941  accuracy: 0.0800  val_accuracy: 0.0700
# Epoch 5/5  loss: 119.1558  val_loss: 117.9941  accuracy: 0.0800  val_accuracy: 0.0700

# %%
model.summary()
# Out:
# ======================================================================
# Model: Sequential
# ======================================================================
# Layer (type)                        Output Shape              Param #
# ----------------------------------------------------------------------
# 0. Dense                            (1, 128)                  100,480
# 1. Dense                            (1, 64)                   8,256
# 2. Dense                            (1, 10)                   650
# ======================================================================
# Total params:         109,386
# Trainable params:     109,386
# Non-trainable params: 0
# ======================================================================

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
from keras import Sequential

# %%
model = Sequential()
model.add(Dense(128, activation='relu',input_shape=(784,)))
model.add(Dense(64,activation='relu'))
model.add(Dense(10, activation='softmax'))
# Out:
# C:\Users\Dell\OneDrive - City Community Education Consultancy Pvt. Ltd\Desktop\ann_engine\venv\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
print(model)
# Out:
# <Sequential name=sequential, built=True>

# %%
model.compile(optimizer="Adam",loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train, y_train,epochs=5,batch_size=32,verbose=1)
# Out:
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.0700 - loss: 3764.1289
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0700 - loss: 4773.8613
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0700 - loss: 5977.5068
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0700 - loss: 7199.4805
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0700 - loss: 8807.3174
