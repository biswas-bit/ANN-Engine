# %%
import numpy as np
from ann_engine.layers.layers import Dense
from ann_engine.layers import Sequential
from ann_engine.optimizers import Adam

# %%
X_train = np.random.randn(1000, 784)
y_train = np.random.randint(0, 10, (1000, 10))

# %%
model1 = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# %%
print(model1)

# %%
model1.compile(optimizer=Adam(lr=0.01),
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])

# %%
history_of_ann_engine = model1.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100  loss: 10.8898  val_loss: 11.0094  accuracy: 0.0912  val_accuracy: 0.0750
# Epoch 11/100  loss: 10.8898  val_loss: 11.0094  accuracy: 0.0912  val_accuracy: 0.0750
# Epoch 21/100  loss: 10.8898  val_loss: 11.0094  accuracy: 0.0912  val_accuracy: 0.0750
# Epoch 31/100  loss: 10.8898  val_loss: 11.0094  accuracy: 0.0912  val_accuracy: 0.0750
# Epoch 41/100  loss: 10.8898  val_loss: 11.0094  accuracy: 0.0912  val_accuracy: 0.0750
# Epoch 51/100  loss: 10.8898  val_loss: 11.0094  accuracy: 0.0912  val_accuracy: 0.0750
# Epoch 61/100  loss: 10.8898  val_loss: 11.0094  accuracy: 0.0912  val_accuracy: 0.0750
# Epoch 71/100  loss: 10.8898  val_loss: 11.0094  accuracy: 0.0912  val_accuracy: 0.0750
# Epoch 81/100  loss: 10.8898  val_loss: 11.0094  accuracy: 0.0912  val_accuracy: 0.0750
# Epoch 91/100  loss: 10.8898  val_loss: 11.0094  accuracy: 0.0912  val_accuracy: 0.0750
# Epoch 100/100  loss: 10.8898  val_loss: 11.0094  accuracy: 0.0912  val_accuracy: 0.0750
