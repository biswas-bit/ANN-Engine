# %%
import numpy as np
from ann_engine.layers.layers import Dense
from ann_engine.layers import Sequential
from ann_engine.optimizers import Adam

# %%
X_train = np.random.randn(1000, 784)
y_train = np.random.randint(0, 10, (1000, 10))

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# %%
print(model)
# Out:
# <ann_engine.layers.sequential.Sequential object at 0x000001DB7563B590>

# %%
model.compile(optimizer=Adam(lr=0.01),
             loss = 'mse',
             metrics = ['mae'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model.compile(optimizer=Adam(lr=0.01),
#       2              loss = 'mse',
#       3              metrics = ['mae'])
#
# TypeError: Adam.__init__() missing 1 required positional argument: 'parameters'
